# %%
import matplotlib as pyplotimport mathb = 100.0v = 1e = 0.99umax = 2.0edge = 0.5

# %%
def darF (d,ps):    x = d    Val = 0.0    if (x<edge):        Val = -b*e*ps    if (x>edge):        Val = -b*(e-v)*ps    if (x==edge):        Val = -b(e-0.5*v)*ps        return Val

# %%
#función simétricapsio = 1.0dpo = 0.0uo = 0.0du = 0.01u = uopsi = psiodp = dpoF = darF(u,psi)dp = dp + 0.5*F*dupsi = psi + dp*dulistu = []listpsi = []

# %%
#Euler Feynmanwhile u < umax:    u = u + du    dp = dp + F*du    psi = psi + dp*du    F=darF(u, psi)        listu.append(u)    listpsi.append(psi)    print u, psi
# Out:
# 0.01 0.98020.02 0.955646020.03 0.9216311444020.04 0.8784921204740.05 0.8266560245540.06 0.7666360339910.07 0.6990263466910.08 0.6244962985590.09 0.5437837370710.1 0.4576877165860.11 0.3670605877070.12 0.272799559010.13 0.1758378146780.14 0.07713527598130.15 -0.02233090194780.16 -0.1215760039480.17 -0.2196175035080.18 -0.3154847897840.19 -0.4082287766410.2 -0.496931298610.21 -0.5807142007220.22 -0.6587480322470.23 -0.7302602582530.24 -0.7945429077020.25 -0.8509595823640.26 -0.8989517571620.27 -0.9380443095630.28 -0.96785022330.29 -0.9880744198260.3 -0.9985166795960.31 -0.9990736242380.32 -0.989739740.33 -0.9706074323360.34 -0.9418661110910.35 -0.9038003153470.36 -0.8567868964820.37 -0.801291287340.38 -0.7378628944550.39 -0.6671296589140.4 -0.589791839750.41 -0.5066150813720.42 -0.4184228336890.43 -0.3260881999520.44 -0.2305252930360.45 -0.1326801857180.46 -0.03352154456220.47 0.06596895988490.48 0.1648063716290.49 0.2620122002940.5 0.3566241081760.51 0.451271678470.52 0.545964375930.5
# ...

# %%
matplotlib.pyplot.scatter(listu,listpsi)pylab.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/nico/Schrodinger/<ipython-input-9-e133f0d78c3c> in <module>()
# ----> 1 matplotlib.pyplot.scatter(listu,listpsi)
#       2
#       3 pylab.show()
#
# AttributeError: 'module' object has no attribute 'pyplot'
